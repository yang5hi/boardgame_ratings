# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# read in csv file
game_info_df=pd.read_csv("../data/boardgames_07022021.csv")
# remove duplicate games
game_info_df.drop_duplicates(subset=['objectid'], inplace=True)
# =========================================================================================================
# choose the features based on correlations
game_info_df=game_info_df[['average', 'numwanting', 'siteviews', 'blogs', 'minage', 'news',
                           'podcast', 'totalvotes', 'numcomments', 'numgeeklists', 'weblink']].copy()
# =========================================================================================================
# remove the rows which have invalid values
game_info_df.drop(game_info_df[game_info_df['average'] ==0].index, inplace = True)
game_info_df.drop(game_info_df[game_info_df['totalvotes'] ==0].index, inplace = True)
# drop the null rows
game_info_df.dropna(inplace=True)
game_info_df.head()
# Out:
#    average  numwanting  siteviews  blogs  minage  news  podcast  totalvotes  \
# 0  8.77503        1374   10583753    690      14     8      147        1171
# 1  8.60721         850    3385064    653      13    10      170         668
# 2  8.66981        1477    1816252    208      14     4       28         521
# 3  8.42870        2085    6059031   1473      12    16      163        1800
# 4  8.68957         979    2267902     99      14     3       53         335
#
#    numcomments  numgeeklists  weblink
# 0         8021          4649       40
# 1         6552          3978       70
# 2         3303          1630       23
# 3        10034          7276       71
# 4         2206          1010       23

# %%
# Get the general idea about the dataset value range
game_info_df.describe().T
# Out:
#                 count          mean            std     min          25%  \
# average       20138.0      6.434485       0.938374     1.0      5.86667
# numwanting    20138.0     43.792879     121.608511     0.0      3.00000
# siteviews     20138.0  92644.494091  261624.524627  1431.0  14757.00000
# blogs         20138.0     12.260701      45.139607     0.0      0.00000
# minage        20138.0      9.598073       3.710556     0.0      8.00000
# news          20138.0      0.580197       1.396812     0.0      0.00000
# podcast       20138.0      2.137899       8.391469     0.0      0.00000
# totalvotes    20138.0     16.454067      66.393870     1.0      2.00000
# numcomments   20138.0    219.157364     676.344229     0.0     23.00000
# numgeeklists  20138.0    259.978101    1183.245497     0.0     24.00000
# weblink       20138.0      6.637352      11.384822     0.0      1.00000
#
#                        50%           75%         max
# average           6.472555      7.058972         9.5
# numwanting        9.000000     30.000000      2085.0
# siteviews     29878.500000  72693.500000  10583753.0
# blogs             2.000000      8.000000      1473.0
# minage           10.000000     12.000000        25.0
# news              0.000000      1.000000        37.0
# podcast           0.000000      1.000000       588.0
# totalvotes        3.000000      9.000000      2108.0
# numcomments      53.000000    146.000000     18840.0
# numgeeklists     63.000000    195.000000    136869.0
# weblink           3.000000      7.000000       207.0

# %% [markdown]
# ## Select features, Scale the data

# %%
# Set features (X) and target (y)
y=game_info_df['average']
X=game_info_df.drop(['average'],axis=1)

# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X)
X_scaled = X_scaler.transform(X)

X_scaled.shape, y.shape
# Out:
# ((20138, 10), (20138,))

# %% [markdown]
# ## AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
 # Create a random forest regressor
abr = AdaBoostRegressor(n_estimators=1000)
abr = abr.fit(X_scaled, y)
print(f"Training Data Score: {abr.score(X_scaled, y):.5f}")
# Out:
# Training Data Score: 0.36872

# %%
# Create the GridSearchCV model
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [50,200,500,1000],
              'loss': ['linear', 'square', 'exponential']}
grid = GridSearchCV(abr, param_grid, verbose=3, scoring="neg_mean_squared_error",return_train_score=True)

# Train the model with GridSearch
grid.fit(X_scaled, y)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END loss=linear, n_estimators=50;, score=(train=-0.614, test=-0.675) total time=   0.3s
# [CV 2/5] END loss=linear, n_estimators=50;, score=(train=-0.609, test=-0.726) total time=   0.5s
# [CV 3/5] END loss=linear, n_estimators=50;, score=(train=-0.520, test=-0.793) total time=   0.3s
# [CV 4/5] END loss=linear, n_estimators=50;, score=(train=-0.610, test=-0.395) total time=   0.5s
# [CV 5/5] END loss=linear, n_estimators=50;, score=(train=-0.360, test=-2.450) total time=   0.6s
# [CV 1/5] END loss=linear, n_estimators=200;, score=(train=-0.623, test=-0.582) total time=   0.3s
# [CV 2/5] END loss=linear, n_estimators=200;, score=(train=-0.557, test=-0.553) total time=   0.2s
# [CV 3/5] END loss=linear, n_estimators=200;, score=(train=-0.530, test=-0.834) total time=   0.3s
# [CV 4/5] END loss=linear, n_estimators=200;, score=(train=-0.646, test=-0.405) total time=   0.6s
# [CV 5/5] END loss=linear, n_estimators=200;, score=(train=-0.399, test=-2.587) total time=   1.1s
# [CV 1/5] END loss=linear, n_estimators=500;, score=(train=-0.608, test=-0.567) total time=   0.5s
# [CV 2/5] END loss=linear, n_estimators=500;, score=(train=-0.578, test=-0.622) total time=   0.4s
# [CV 3/5] END loss=linear, n_estimators=500;, score=(train=-0.521, test=-0.840) total time=   0.3s
# [CV 4/5] END loss=linear, n_estimators=500;, score=(train=-0.657, test=-0.393) total time=   0.6s
# [CV 5/5] END loss=linear, n_estimators=500;, score=(train=-0.392, test=-2.564) total time=   0.9s
# [CV 1/5] END loss=linear, n_estimators=1000;, score=(train=-0.609, test=-0.728) total time=   0.2s
# [CV 2/5] END loss=linear, n_estimators=1000;, score=(train=-0.560, test=-0.560) total time=   0.2s
# [CV 3/5] END loss=linear, n_estimators=1000;, score=(train=-0.519, test=-0.833) total time=   0.3s
# [CV 4/5] END loss=linear, n_estimators=1000;, score=(train=-0.650, test=-0.377) total time=   0.6s
# [CV 5/5] END loss=linear, n_estimators=1000;, score=(train=-0.350, test=-2.425) total time=   0.4s
# [CV 1/5] END loss=square, n_estimators=50;, score=(train=-0.655, test=-0.798) total time=   0.5s
# [CV 2/5] END loss=square, n_estimators=50;, score=(train=-0.689, test=-0.836) total time=   0.5s
# [CV 3/5] END loss=square, n_estimators=50;, score=(train=-0.592, test=-1.028) total time=   0.4s
# [CV 4/5] END loss=square, n_estimators=50;, score=(train=-0.692, test=-0.407) total time=   0.5s
# [CV 5/5] END loss=square, n_estimators=50;, score=(train=-0.450, test=-2.725) total time=   0.5s
# [CV 1/5] END loss=square, n_estimators=200;, score=(train=-0.735, test=-0.987) total time=   1.9s
# [CV 2/5] END loss=square, n_estimators=200;, score=(train=-0.765, test=-0.967) total time=   1.8s
# [CV 3/5] END loss=square, n_estimators=200;, score=(train=-0.692, test=-1.049) total time=   2.0s
# [CV 4/5] END loss=square, n_estimators=200;, score=(train=-0.927, test=-0.417) total time=   1.8s
# [CV 5/5] END loss=square, n_estimators=200;, score=(train=-0.493, test=-2.901) total time=   2.2s
# [CV 1/5] END loss=square, n_estimators=500;, score=(train=-0.778, test=-1.088) total time=   4.6s
# [CV 2/5] END loss=square, n_estimators=500;, score=(train=-0.766, test=-1.010) total time=   4.6s
# [CV 3/5] END loss=square, n_estimators=500;, score=(train=-0.722, test=-1.166) total time=   4.5s
# [CV 4/5] END loss=square, n_estimators=500;, score=(train=-1.030, test=-0.453) total time=   4.6s
# [CV 5/5] END loss=square, n_estimators=500;, score=(train=-0.527, test=-2.946) total time=   5.0s
# [CV 1/5] END loss=square, n_estimators=1000;, score=(train=-0.791, test=-1.131) total time=   8.9s
# [CV 2/5] END loss=square, n_estimators=1000;, score=(train=-0.781, test=-1.107) total time=   9.0s
# [CV 3/5] END loss=square, n_estimators=1000;, score=(train=-0.698, test=-1.127) total time=   9.1s
# [CV 4/5] END loss=square, n_estimators=1000;, score=(train=-1.067, test=-0.453) total time=   9.1s
# [CV 5/5] END loss=square, n_estimators=1000;, score=(train=-0.518, test=-2.975) total time=  10.0s
# [CV 1/5] END loss=exponential, n_estimators=50;, score=(train=-0.636, test=-0.697) total time=   0.5s
# [CV 2/5] END loss=exponential, n_estimators=50;, score=(train=-0.621, test=-0.751) total time=   0.5s
# [CV 3/5] END loss=exponential, n_estimators=50;, score=(train=-0.553, test=-0.908) total time=   0.6s
# [CV 4/5] END loss=exponential, n_estimators=50;, score=(train=-0.652, test=-0.376) total time=   0.6s
# [CV 5/5] END loss=exponential, n_estimators=50;, score=(train=-0.368, test=-2.484) total time=   0.7s
# [CV 1/5] END loss=exponential, n_estimators=200;, score=(train=-0.771, test=-1.300) total time=   2.0s
# [CV 2/5] END loss=exponential, n_estimators=200;, score=(train=-0.840, test=-1.191) total time=   1.9s
# [CV 3/5] END loss=exponential, n_estimators=200;, score=(train=-0.755, test=-1.016) total time=   1.9s
# [CV 4/5] END loss=exponential, n_estimators=200;, score=(train=-1.069, test=-0.403) total time=   2.0s
# [CV 5/5] END loss=exponential, n_estimators=200;, score=(train=-0.487, test=-2.928) total time=   2.3s
# [CV 1/5] END loss=exponential, n_estimators=500;, score=(train=-0.839, test=-1.502) total time=   4.6s
# [CV 2/5] END loss=exponential, n_estimators=500;, score=(train=-0.943, test=-1.162) total time=   4.6s
# [CV 3/5] END loss=exponential, n_estimators=500;, score=(train=-0.830, test=-1.138) total time=   4.5s
# [CV 4/5] END loss=exponential, n_estimators=500;, score=(train=-1.211, test=-0.419) total time=   4.6s
# [CV 5/5] END loss=exponential, n_estimators=500;, score=(train=-0.528, test=-3.006) total time=   5.3s
# [CV 1/5] END loss=exponential, n_estimators=1000;, score=(train=-0.859, test=-1.637) total time=   9.0s
# [CV 2/5] END loss=exponential, n_estimators=1000;, score=(train=-0.936, test=-1.117) total time=   9.0s
# [CV 3/5] END loss=exponential, n_estimators=1000;, score=(train=-0.967, test=-1.275) total time=   8.9s
# [CV 4/5] END loss=exponential, n_estimators=1000;, score=(train=-1.328, test=-0.440) total time=   9.0s
# [CV 5/5] END loss=exponential, n_estimators=1000;, score=(train=-0.539, test=-3.086) total time=  10.0s
# {'loss': 'linear', 'n_estimators': 1000}
# -0.9845048480285422

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score

# get the model predictions
predictions = grid.predict(X_scaled)

print(f"Grid Best Explained Variance Score: {explained_variance_score(y, predictions):.5f}")
print(f"Grid Best R2 Score: {r2_score(y, predictions):.5f}")
# Out:
# Grid Best Explained Variance Score: 0.38628
# Grid Best R2 Score: 0.32659

# %%
# %matplotlib inline

fig = plt.figure()
#add subplots
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(233)
# Plot predictions vs actual values
ax1.scatter(predictions, y,alpha=0.2)
ax1.plot([y.min(), y.max()],[y.min(), y.max()],'--r', linewidth=2)
ax1.set_xlim([y.min(), y.max()])
ax1.set_xlabel('Predicted')
ax1.set_ylabel('Actual')
# Plot Residuals
ax2.scatter(predictions, predictions - y,alpha=0.2)
ax2.hlines(y=0, xmin=y.min(), xmax=y.max(),colors="r", linestyles='dashed', )
ax2.set_xlim([y.min(), y.max()])
ax2.set_ylim([-6,6])
ax2.set_xlabel('Predicted')
ax2.set_ylabel('Residual')
plt.show()

# %%
fig.savefig("abr.svg", dpi=150)
fig.savefig("abr.png", dpi=150)
