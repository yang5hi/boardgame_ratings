# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# read in csv file
game_info_df=pd.read_csv("../data/boardgames_07022021.csv")
# remove duplicate games
game_info_df.drop_duplicates(subset=['objectid'], inplace=True)
# =========================================================================================================
# choose the features based on correlations
game_info_df=game_info_df[['average', 'numwanting', 'siteviews', 'blogs', 'minage', 'news',
                           'podcast', 'totalvotes', 'numcomments', 'numgeeklists', 'weblink']].copy()
# =========================================================================================================
# remove the rows which have invalid values
game_info_df.drop(game_info_df[game_info_df['average'] ==0].index, inplace = True)
game_info_df.drop(game_info_df[game_info_df['totalvotes'] ==0].index, inplace = True)
# drop the null rows
game_info_df.dropna(inplace=True)
game_info_df.head()
# Out:
#    average  numwanting  siteviews  blogs  minage  news  podcast  totalvotes  \
# 0  8.77503        1374   10583753    690      14     8      147        1171
# 1  8.60721         850    3385064    653      13    10      170         668
# 2  8.66981        1477    1816252    208      14     4       28         521
# 3  8.42870        2085    6059031   1473      12    16      163        1800
# 4  8.68957         979    2267902     99      14     3       53         335
#
#    numcomments  numgeeklists  weblink
# 0         8021          4649       40
# 1         6552          3978       70
# 2         3303          1630       23
# 3        10034          7276       71
# 4         2206          1010       23

# %%
# Get the general idea about the dataset value range
game_info_df.describe().T
# Out:
#                 count          mean            std     min          25%  \
# average       20138.0      6.434485       0.938374     1.0      5.86667
# numwanting    20138.0     43.792879     121.608511     0.0      3.00000
# siteviews     20138.0  92644.494091  261624.524627  1431.0  14757.00000
# blogs         20138.0     12.260701      45.139607     0.0      0.00000
# minage        20138.0      9.598073       3.710556     0.0      8.00000
# news          20138.0      0.580197       1.396812     0.0      0.00000
# podcast       20138.0      2.137899       8.391469     0.0      0.00000
# totalvotes    20138.0     16.454067      66.393870     1.0      2.00000
# numcomments   20138.0    219.157364     676.344229     0.0     23.00000
# numgeeklists  20138.0    259.978101    1183.245497     0.0     24.00000
# weblink       20138.0      6.637352      11.384822     0.0      1.00000
#
#                        50%           75%         max
# average           6.472555      7.058972         9.5
# numwanting        9.000000     30.000000      2085.0
# siteviews     29878.500000  72693.500000  10583753.0
# blogs             2.000000      8.000000      1473.0
# minage           10.000000     12.000000        25.0
# news              0.000000      1.000000        37.0
# podcast           0.000000      1.000000       588.0
# totalvotes        3.000000      9.000000      2108.0
# numcomments      53.000000    146.000000     18840.0
# numgeeklists     63.000000    195.000000    136869.0
# weblink           3.000000      7.000000       207.0

# %% [markdown]
# ## Select features, Create Train Test Split, Scale the data

# %%
# Set features (X) and target (y)
y=game_info_df['average']
X=game_info_df.drop(['average'],axis=1)

# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X)
X_scaled = X_scaler.transform(X)

X_scaled.shape, y.shape
# Out:
# ((20138, 10), (20138,))

# %% [markdown]
# ## KNeighborRegressor

# %%
from sklearn.neighbors import KNeighborsRegressor
 # Create a k neighbors regressor
knr = KNeighborsRegressor(n_neighbors=3)
knr=knr.fit(X_scaled, y)
print(f"Training Data Score: {knr.score(X_scaled, y):.5f}")
# Out:
# Training Data Score: 0.66311

# %%
# Create the GridSearchCV model
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'n_neighbors': range(1, 30, 2)}

grid = GridSearchCV(knr, param_grid, verbose=3)

# Train the model with GridSearch
grid.fit(X_scaled, y)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5] END ....................n_neighbors=1;, score=-1.703 total time=   0.1s
# [CV 2/5] END ....................n_neighbors=1;, score=-1.082 total time=   0.0s
# [CV 3/5] END ....................n_neighbors=1;, score=-1.674 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=1;, score=-3.241 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=1;, score=-0.719 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=3;, score=-0.829 total time=   0.1s
# [CV 2/5] END ....................n_neighbors=3;, score=-0.384 total time=   0.1s
# [CV 3/5] END ....................n_neighbors=3;, score=-0.891 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=3;, score=-1.498 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=3;, score=-0.561 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=5;, score=-0.614 total time=   0.1s
# [CV 2/5] END ....................n_neighbors=5;, score=-0.285 total time=   0.1s
# [CV 3/5] END ....................n_neighbors=5;, score=-0.777 total time=   0.0s
# [CV 4/5] END ....................n_neighbors=5;, score=-1.150 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=5;, score=-0.552 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=7;, score=-0.563 total time=   0.2s
# [CV 2/5] END ....................n_neighbors=7;, score=-0.242 total time=   0.1s
# [CV 3/5] END ....................n_neighbors=7;, score=-0.759 total time=   0.1s
# [CV 4/5] END ....................n_neighbors=7;, score=-1.007 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=7;, score=-0.550 total time=   0.0s
# [CV 1/5] END ....................n_neighbors=9;, score=-0.546 total time=   0.2s
# [CV 2/5] END ....................n_neighbors=9;, score=-0.232 total time=   0.1s
# [CV 3/5] END ....................n_neighbors=9;, score=-0.744 total time=   0.1s
# [CV 4/5] END ....................n_neighbors=9;, score=-0.884 total time=   0.0s
# [CV 5/5] END ....................n_neighbors=9;, score=-0.549 total time=   0.0s
# [CV 1/5] END ...................n_neighbors=11;, score=-0.559 total time=   0.2s
# [CV 2/5] END ...................n_neighbors=11;, score=-0.221 total time=   0.1s
# [CV 3/5] END ...................n_neighbors=11;, score=-0.743 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=11;, score=-0.830 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=11;, score=-0.557 total time=   0.0s
# [CV 1/5] END ...................n_neighbors=13;, score=-0.575 total time=   0.2s
# [CV 2/5] END ...................n_neighbors=13;, score=-0.217 total time=   0.1s
# [CV 3/5] END ...................n_neighbors=13;, score=-0.747 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=13;, score=-0.791 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=13;, score=-0.561 total time=   0.0s
# [CV 1/5] END ...................n_neighbors=15;, score=-0.597 total time=   0.2s
# [CV 2/5] END ...................n_neighbors=15;, score=-0.224 total time=   0.1s
# [CV 3/5] END ...................n_neighbors=15;, score=-0.740 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=15;, score=-0.769 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=15;, score=-0.571 total time=   0.0s
# [CV 1/5] END ...................n_neighbors=17;, score=-0.618 total time=   0.2s
# [CV 2/5] END ...................n_neighbors=17;, score=-0.229 total time=   0.1s
# [CV 3/5] END ...................n_neighbors=17;, score=-0.744 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=17;, score=-0.747 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=17;, score=-0.580 total time=   0.0s
# [CV 1/5] END ...................n_neighbors=19;, score=-0.631 total time=   0.2s
# [CV 2/5] END ...................n_neighbors=19;, score=-0.224 total time=   0.1s
# [CV 3/5] END ...................n_neighbors=19;, score=-0.739 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=19;, score=-0.727 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=19;, score=-0.590 total time=   0.1s
# [CV 1/5] END ...................n_neighbors=21;, score=-0.656 total time=   0.2s
# [CV 2/5] END ...................n_neighbors=21;, score=-0.230 total time=   0.2s
# [CV 3/5] END ...................n_neighbors=21;, score=-0.746 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=21;, score=-0.712 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=21;, score=-0.597 total time=   0.1s
# [CV 1/5] END ...................n_neighbors=23;, score=-0.665 total time=   0.2s
# [CV 2/5] END ...................n_neighbors=23;, score=-0.236 total time=   0.1s
# [CV 3/5] END ...................n_neighbors=23;, score=-0.754 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=23;, score=-0.710 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=23;, score=-0.603 total time=   0.1s
# [CV 1/5] END ...................n_neighbors=25;, score=-0.684 total time=   0.3s
# [CV 2/5] END ...................n_neighbors=25;, score=-0.241 total time=   0.1s
# [CV 3/5] END ...................n_neighbors=25;, score=-0.763 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=25;, score=-0.704 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=25;, score=-0.611 total time=   0.1s
# [CV 1/5] END ...................n_neighbors=27;, score=-0.698 total time=   0.3s
# [CV 2/5] END ...................n_neighbors=27;, score=-0.242 total time=   0.2s
# [CV 3/5] END ...................n_neighbors=27;, score=-0.763 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=27;, score=-0.696 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=27;, score=-0.616 total time=   0.1s
# [CV 1/5] END ...................n_neighbors=29;, score=-0.708 total time=   0.3s
# [CV 2/5] END ...................n_neighbors=29;, score=-0.244 total time=   0.2s
# [CV 3/5] END ...................n_neighbors=29;, score=-0.760 total time=   0.1s
# [CV 4/5] END ...................n_neighbors=29;, score=-0.677 total time=   0.1s
# [CV 5/5] END ...................n_neighbors=29;, score=-0.620 total time=   0.1s
# {'n_neighbors': 13}
# -0.5782623053392963

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score

# get the model predictions
predictions = grid.predict(X_scaled)

print(f"Grid Best Explained Variance Score: {explained_variance_score(y, predictions):.5f}")
print(f"Grid Best R2 Score: {r2_score(y, predictions):.5f}")
# Out:
# Grid Best Explained Variance Score: 0.50760
# Grid Best R2 Score: 0.50689

# %%
# %matplotlib inline

fig = plt.figure()
#add subplots
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(233)
# Plot predictions vs actual values
ax1.scatter(predictions, y,alpha=0.2)
ax1.plot([y.min(), y.max()],[y.min(), y.max()],'--r', linewidth=2)
ax1.set_xlim([y.min(), y.max()])
ax1.set_xlabel('Predicted')
ax1.set_ylabel('Actual')
# Plot Residuals
ax2.scatter(predictions, predictions - y,alpha=0.2)
ax2.hlines(y=0, xmin=y.min(), xmax=y.max(),colors="r", linestyles='dashed', )
ax2.set_xlim([y.min(), y.max()])
ax2.set_ylim([-6,6])
ax2.set_xlabel('Predicted')
ax2.set_ylabel('Residual')
plt.show()

# %%
fig.savefig("knr.svg", dpi=150)
fig.savefig("knr.png", dpi=150)
