# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read the CSV and Perform Basic Data Cleaning
# ### Here is the list of contributions
# * objectid - the identifier on boardgamegeeks.com
# * name - name of the game
# * yearpublished - the year the game was published
# * sortindex - rank of the game on bbg.com
# * minplayer - minumum number of players per the publishers
# * maxplayers - maximum number of players per the publishers
# * minplaytime - minimum playtime required per the publishers
# * maxplaytime - maximum playtime per the publishers
# * minage - minimum age requiremnet per the publishers
# * min_community - minimum players per the community
# * max_community - max players per the community
# * totalvotes - total number of community vote
# * playerage - minimum age requirement per the community
# * languagedependence - a rank of amount of in-game text is required during game play (1: none, 5: unplayable in other language)
# * userrated - number of users that have rated the game
# * average - user average rating from 1-10
# * baverage - from the site, determined to be an anti-skewing effort by bgg with system added mid range ratings (from 1-10)
# * stddev - average standard deviation of a rating
# * avgweight - a complexity rating from 1-5 Weight
# * numweights - number of weight votes
# * numgeeklists - number of geeks with game on list
# * numtrading - number of people trading the game
# * numwanting - number of people wanting the game
# * numcomments - number of comments on the site on this game
# * siteviews - number of views on the site
# * numplays - number of times game was played (according to site users?)
# * numplays_month - number of plays per month
# * news - number news articles on game
# * logs - number of blogs regarding game
# * weblink - number of weblinks for the game
# * podcast - number of podcasts on the game
# * label - category of game (mostly boardgame)
# * boardgamedesigner_cnt - count of designers
# * boardgameartist_cnt - artist count
# * boardgamepublisher_cnt - publisher count
# * boardgamehonor_cnt - awards count
# * boardgamecategory_cnt - category count
# * boardgamemechanic_cnt - game mechanics count
# * boardgameexpansion_cnt - expansion count
# * boardgameversion_cnt - version count (languages)
# * boardgamefamily_cnt - game family count
# * boardgamedesigner - list of game designers
# * boardgameartist - list of game artists
# * boardgamepublisher - list of publishers
# * boardgamehonor - list of awards
# * boardgamecategory - list of categories
# * boardgameversion - list of versions
# * boardgamemechanic - a list of mechanics
# * boardgameexpansion - a list of expansions
# * boardgamefamily - a list of boardgames family
# * description - full text description of game
# * gamelink - a link to the game on bgg.com

# %%
game_info_df=pd.read_csv("../data/boardgames_07022021.csv")
game_info_df.head()
# Out:
#    objectid                               name  yearpublished  sortindex  \
# 0    174430                         Gloomhaven           2017          1
# 1    161936          Pandemic Legacy  Season 1           2015          2
# 2    224517                  Brass  Birmingham           2018          3
# 3    167791                  Terraforming Mars           2016          4
# 4    233078  Twilight Imperium  Fourth Edition           2017          5
#
#    minplayers  maxplayers  minplaytime  maxplaytime  minage  min_community  \
# 0           1           4           60          120      14            3.0
# 1           2           4           60           60      13            4.0
# 2           2           4           60          120      14            3.0
# 3           1           5          120          120      12            3.0
# 4           3           6          240          480      14            6.0
#
#    ...                                    boardgameartist  \
# 0  ...  ['Alexandr Elichev', 'Josh T. McDowell', 'Alva...
# 1  ...                                ['Chris Quilliams']
# 2  ...  ['Lina Cossette', 'David Forest', 'Damien Mamm...
# 3  ...                                ['Isaac Fryxelius']
# 4  ...                                ['Scott Schomburg']
#
#                                   boardgamepublisher  \
# 0  ['Cephalofair Games', 'Albi', 'Albi Polska', '...
# 1  ['Z-Man Games', 'Asterion Press', 'Devir', 'Fi...
# 2  ['Roxley', 'Arclight', 'BoardM Factory', 'Conc...
# 3  ['FryxGames', 'Arclight', 'Bru00e4dspel.se', '...
# 4  ['Fantasy Flight Games', 'ADC Blackfire Entert...
#
#                                       boardgamehonor  \
# 0  ['2017 Best Science Fiction or Fantasy Board G...
# 1  ['2015 Board Game Quest Awards Best Coop Game ...
# 2  ['2018 Board Game Quest Awards Best Production...
# 3  ['2016 Board Game Quest Awards Best Strategy/E...
# 4  ['2017 Golden Geek Best Strategy Board Game No...
#
#                                    boardgamecategory  \
# 0  ['Adventure', 'Exploration', 'Fantasy', 'Fight...
# 1                       ['Environmental', 'Medical']
# 2  ['Economic', 'Industry / Manufacturing', 'Tran...
# 3  ['Economic', 'Environmental', 'Industry / Manu...
# 4  ['Civilization', 'Economic', 'Exploration', 'N...
#
#                                     boardgameversion  \
# 0  ['Chinese edition', 'Czech edition', 'English ...
# 1  ['Chinese blue edition', 'Chinese red edition'...
# 2  ['Chinese edition', 'Czech/English edition', '...
# 3  ['Bulgarian edition', 'Chinese edition', 'Chin...
# 4  ['Chinese edition', 'Czech edition', 'English ...
#
#                                    boardgamemechanic  \
# 0  ['Action Queue', 'Action Retrieval', 'Campaign...
# 1  ['Action Points', 'Cooperative Game', 'Hand Ma...
# 2  ['Hand Management', 'Income', 'Loans', 'Market...
# 3  ['Drafting', 'End Game Bonuses', 'Hand Managem...
# 4  ['Action Drafting', 'Area Majority / Influence...
#
#                                   boardgameexpansion  \
# 0  ['Gloomhaven: Assault on the Morning Star (Pro...
# 1                                           ['None']
# 2                                           ['None']
# 3  ['French Championship Promo Cards (fan expansi...
# 4  ['Twilight Imperium: Fourth Edition u2013 Prop...
#
#                                      boardgamefamily  \
# 0  ['Category: Dungeon Crawler', 'Components: Min...
# 1  ['Components: Map (Global Scale)', 'Game: Pand...
# 2  ['Cities: Birmingham (England)', 'Country: Eng...
# 3  ['Components: Map (Global Scale)', 'Components...
# 4  ['Components: Hexagonal Tiles', 'Components: M...
#
#                                          description  \
# 0  Vanquish monsters with strategic cardplay. Ful...
# 1  Mutating diseases are spreading around the wor...
# 2  Build networks, grow industries, and navigate ...
# 3  Compete with rival CEOs to make Mars habitable...
# 4  Build an intergalactic empire through trade, r...
#
#                                             gamelink
# 0                       /boardgame/174430/gloomhaven
# 1         /boardgame/161936/pandemic-legacy-season-1
# 2                 /boardgame/224517/brass-birmingham
# 3                /boardgame/167791/terraforming-mars
# 4  /boardgame/233078/twilight-imperium-fourth-edi...
#
# [5 rows x 52 columns]

# %%
# remove duplicate games
game_info_df.drop_duplicates(subset=['objectid'], inplace=True)
# choose the attributes which have numerical datatype
game_info_df=game_info_df[['average', 'yearpublished',  'minplayers',
       'maxplayers', 'minplaytime', 'maxplaytime', 'minage', 'totalvotes', 'languagedependence',
       'usersrated', 'stddev', 'avgweight','numweights', 'numgeeklists', 'numtrading', 'numwanting', 'numcomments',
       'siteviews', 'numplays', 'numplays_month', 'news', 'blogs', 'weblink',
       'podcast',  'boardgamedesigner_cnt', 'boardgameartist_cnt',
       'boardgamepublisher_cnt', 'boardgamehonor_cnt', 'boardgamecategory_cnt',
       'boardgamemechanic_cnt', 'boardgameexpansion_cnt',
       'boardgameversion_cnt', 'boardgamefamily_cnt']].copy()
# drop the null rows
game_info_df.dropna(inplace=True)
# remove the rows which have invalid values
game_info_df.drop(game_info_df[game_info_df['average'] ==0].index, inplace = True)
game_info_df.drop(game_info_df[game_info_df['minplayers'] ==0].index, inplace = True)
game_info_df.drop(game_info_df[game_info_df['maxplayers'] ==0].index, inplace = True)
game_info_df.drop(game_info_df[game_info_df['minplaytime'] ==0].index, inplace = True)
game_info_df.drop(game_info_df[game_info_df['maxplaytime'] ==0].index, inplace = True)
game_info_df.drop(game_info_df[game_info_df['totalvotes'] ==0].index, inplace = True)
game_info_df.head()
# Out:
#    average  yearpublished  minplayers  maxplayers  minplaytime  maxplaytime  \
# 0  8.77503           2017           1           4           60          120
# 1  8.60721           2015           2           4           60           60
# 2  8.66981           2018           2           4           60          120
# 3  8.42870           2016           1           5          120          120
# 4  8.68957           2017           3           6          240          480
#
#    minage  totalvotes  languagedependence  usersrated  ...  podcast  \
# 0      14        1171                   4       44354  ...      147
# 1      13         668                   4       43007  ...      170
# 2      14         521                   1       21618  ...       28
# 3      12        1800                   3       68412  ...      163
# 4      14         335                   4       14385  ...       53
#
#    boardgamedesigner_cnt  boardgameartist_cnt  boardgamepublisher_cnt  \
# 0                      1                    3                      12
# 1                      2                    1                      11
# 2                      3                    3                      14
# 3                      1                    1                      25
# 4                      3                    1                      11
#
#    boardgamehonor_cnt  boardgamecategory_cnt  boardgamemechanic_cnt  \
# 0                  30                      5                     20
# 1                  30                      2                      8
# 2                  18                      3                      9
# 3                  39                      6                     11
# 4                   2                      8                     14
#
#    boardgameexpansion_cnt  boardgameversion_cnt  boardgamefamily_cnt
# 0                      12                    23                   12
# 1                       0                    33                    7
# 2                       0                    16                    9
# 3                      21                    35                    8
# 4                       3                    12                    5
#
# [5 rows x 33 columns]

# %%
# Get the general idea about the dataset value range
game_info_df.describe().T
# Out:
#                           count          mean            std     min  \
# average                 19316.0      6.448354       0.923534     1.0
# yearpublished           19316.0   1984.922189     203.982472 -3500.0
# minplayers              19316.0      2.008128       0.676124     1.0
# maxplayers              19316.0      5.440930      13.146152     1.0
# minplaytime             19316.0     69.816007     472.459600     1.0
# maxplaytime             19316.0     96.815749     558.755905     1.0
# minage                  19316.0      9.688704       3.611765     0.0
# totalvotes              19316.0     17.054670      67.723891     1.0
# languagedependence      19316.0      1.669704       1.373367     0.0
# usersrated              19316.0    923.496946    3721.562843     1.0
# stddev                  19316.0      1.502877       0.300791     0.0
# avgweight               19316.0      2.040167       0.844400     0.0
# numweights              19316.0     54.691810     215.631358     0.0
# numgeeklists            19316.0    261.421568     690.549399     0.0
# numtrading              19316.0     46.492856     104.965601     0.0
# numwanting              19316.0     45.388642     123.863147     0.0
# numcomments             19316.0    227.181611     689.213188     0.0
# siteviews               19316.0  95715.405519  266620.755430  1455.0
# numplays                19316.0   3034.515997   17229.631698     0.0
# numplays_month          19316.0      0.946573       7.398893     0.0
# news                    19316.0      0.601419       1.420429     0.0
# blogs                   19316.0     12.695434      45.890235     0.0
# weblink                 19316.0      6.851677      11.562909     0.0
# podcast                 19316.0      2.222044       8.557106     0.0
# boardgamedesigner_cnt   19316.0      1.353541       0.791904     0.0
# boardgameartist_cnt     19316.0      1.465624       4.820120     0.0
# boardgamepublisher_cnt  19316.0      2.733899       5.446800     1.0
# boardgamehonor_cnt      19316.0      0.591530       2.127580     0.0
# boardgamecategory_cnt   19316.0      2.644440       1.393190     0.0
# boardgamemechanic_cnt   19316.0      2.935183       2.180217     0.0
# boardgameexpansion_cnt  19316.0      1.416028       7.642378     0.0
# boardgameversion_cnt    19316.0      3.766981      12.650044     0.0
# boardgamefamily_cnt     19316.0      2.144699       2.237845     0.0
#
#                                  25%          50%           75%         max
# average                     5.885825      6.48070      7.063608         9.5
# yearpublished            1998.000000   2010.00000   2016.000000      2022.0
# minplayers                  2.000000      2.00000      2.000000        10.0
# maxplayers                  4.000000      4.00000      6.000000       999.0
# minplaytime                20.000000     37.00000     60.000000     60000.0
# maxplaytime                30.000000     45.00000     90.000000     60000.0
# minage                      8.000000     10.00000     12.000000        25.0
# totalvotes                  2.000000      4.00000      9.000000      2108.0
# languagedependence          1.000000      1.00000      3.000000         5.0
# usersrated                 57.000000    139.00000    449.000000    104891.0
# stddev                      1.309702      1.46393      1.653910         4.5
# avgweight                   1.369075      2.00000      2.589700         5.0
# numweights                  4.000000     11.00000     30.000000      7567.0
# numgeeklists               26.000000     68.00000    206.000000     15950.0
# numtrading                  5.000000     15.00000     43.000000      2477.0
# numwanting                  3.000000     10.00000     32.000000      2085.0
# numcomments                25.000000     57.00000    154.000000     18840.0
# siteviews               15405.000000  31252.50000  75763.000000  10583753.0
# numplays                   73.000000    247.00000   1020.250000    699142.0
# numplays_month              0.000000      0.00000      0.000000       380.0
# news                        0.000000      0.00000      1.000000        37.0
# blogs                       0.000000      2.00000      8.000000      1473.0
# weblink                     1.000000      3.00000      8.000000       207.0
# podcast                     0.000000      0.00000      1.000000       588.0
# boardgamedesigner_cnt       1.000000      1.00000      2.000000        21.0
# boardgameartist_cnt         0.000000      1.00000      2.000000       509.0
# boardgamepublisher_cnt      1.000000      1.00000      3.000000       195.0
# boardgamehonor_cnt          0.000000      0.00000      0.000000        53.0
# boardgamecategory_cnt       2.000000      2.00000      3.000000        14.0
# boardgamemechanic_cnt       1.000000      2.00000      4.000000        20.0
# boardgameexpansion_cnt      0.000000      0.00000      1.000000       513.0
# boardgameversion_cnt        1.000000      2.00000      3.000000      1059.0
# boardgamefamily_cnt         1.000000      2.00000      3.000000       104.0

# %% [markdown]
# ## Select features, Create Train Test Split, Scale the data

# %%
# Set features (X) and target (y)
y=game_info_df['average']
X=game_info_df.drop(['average'],axis=1)
X.shape, y.shape
# Out:
# ((19316, 32), (19316,))

# %%
feature_names=X.columns
feature_names
# Out:
# Index(['yearpublished', 'minplayers', 'maxplayers', 'minplaytime',
#        'maxplaytime', 'minage', 'totalvotes', 'languagedependence',
#        'usersrated', 'stddev', 'avgweight', 'numweights', 'numgeeklists',
#        'numtrading', 'numwanting', 'numcomments', 'siteviews', 'numplays',
#        'numplays_month', 'news', 'blogs', 'weblink', 'podcast',
#        'boardgamedesigner_cnt', 'boardgameartist_cnt',
#        'boardgamepublisher_cnt', 'boardgamehonor_cnt', 'boardgamecategory_cnt',
#        'boardgamemechanic_cnt', 'boardgameexpansion_cnt',
#        'boardgameversion_cnt', 'boardgamefamily_cnt'],
#       dtype='object')

# %%
# Create a Train Test Split (20/80)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,  train_size=0.2,random_state=101)
X_train.shape, y_train.shape
# Out:
# ((3863, 32), (3863,))

# %%
# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %% [markdown]
# ## Perform feature selection

# %%
from sklearn.ensemble import RandomForestRegressor
 # Create a random forest regressor
rf = RandomForestRegressor(n_estimators=500)
rf = rf.fit(X_train_scaled, y_train)
print(f"Training Data Score: {rf.score(X_train_scaled, y_train):.5f}")
print(f"Testing Data Score: {rf.score(X_test_scaled, y_test):.5f}")
# Out:
# Training Data Score: 0.95405
# Testing Data Score: 0.66451

# %%
importances = rf.feature_importances_
rf_feature_importance=sorted(zip(importances, feature_names), reverse=True)
rf_feature_importance
# Out:
# [(0.3005122794385575, 'numwanting'),
#  (0.1489187082287356, 'avgweight'),
#  (0.12920185187401156, 'yearpublished'),
#  (0.06312679101938362, 'stddev'),
#  (0.04981256993339548, 'numtrading'),
#  (0.035091547656289634, 'numplays'),
#  (0.02884759667012076, 'numgeeklists'),
#  (0.025367585105266755, 'siteviews'),
#  (0.022144939267148195, 'usersrated'),
#  (0.015584373230025091, 'numcomments'),
#  (0.015576023897094001, 'maxplaytime'),
#  (0.014641050885101809, 'maxplayers'),
#  (0.013031993136779899, 'boardgamefamily_cnt'),
#  (0.012441333310929554, 'minage'),
#  (0.011960480485483581, 'numweights'),
#  (0.011667812031586837, 'totalvotes'),
#  (0.01033658760087476, 'weblink'),
#  (0.009879923038418642, 'boardgamemechanic_cnt'),
#  (0.009016243826499107, 'minplaytime'),
#  (0.008877848440655813, 'boardgameversion_cnt'),
#  (0.008787627686226554, 'boardgameexpansion_cnt'),
#  (0.008678093881420238, 'blogs'),
#  (0.008393481469947603, 'boardgamecategory_cnt'),
#  (0.008334695221104358, 'languagedependence'),
#  (0.006184431397936777, 'boardgamepublisher_cnt'),
#  (0.005891673158289092, 'boardgamedesigner_cnt'),
#  (0.005874592961097403, 'boardgameartist_cnt'),
#  (0.00359576801167175, 'podcast'),
#  (0.0033032317569865266, 'minplayers'),
#  (0.001832955608733866, 'numplays_month'),
#  (0.0015434253990699034, 'boardgamehonor_cnt'),
#  (0.001542484371157706, 'news')]

# %%
plt.pie([a[0] for a in rf_feature_importance],labels=[a[1] for a in rf_feature_importance])
plt.show()

# %%
from sklearn import tree
dtr = tree.DecisionTreeRegressor()
dtr = dtr.fit(X_train_scaled, y_train)
dtr.score(X_train_scaled, y_train)
print(f"Training Data Score: {dtr.score(X_train_scaled, y_train):.5f}")
print(f"Testing Data Score: {dtr.score(X_test_scaled, y_test):.5f}")
# Out:
# Training Data Score: 1.00000
# Testing Data Score: 0.27590

# %%
importances = dtr.feature_importances_
dtr_feature_importance=sorted(zip(importances, feature_names), reverse=True)
dtr_feature_importance
# Out:
# [(0.299655850454725, 'numwanting'),
#  (0.14774687320833704, 'avgweight'),
#  (0.1309827495154494, 'yearpublished'),
#  (0.061935659262216954, 'stddev'),
#  (0.050214361838167416, 'numtrading'),
#  (0.0341415223674313, 'numplays'),
#  (0.031595263557495555, 'numgeeklists'),
#  (0.024648348179448734, 'usersrated'),
#  (0.02423219299611407, 'siteviews'),
#  (0.023143775442881175, 'maxplayers'),
#  (0.0209758711472944, 'numcomments'),
#  (0.01567165612544067, 'minage'),
#  (0.014796816157268125, 'totalvotes'),
#  (0.011370464248952564, 'minplaytime'),
#  (0.010069682663287848, 'numweights'),
#  (0.010031545942658648, 'boardgameexpansion_cnt'),
#  (0.009720315078740995, 'maxplaytime'),
#  (0.009355275717622452, 'boardgameversion_cnt'),
#  (0.0092016274391285, 'boardgamefamily_cnt'),
#  (0.007977992907269846, 'boardgamecategory_cnt'),
#  (0.007569101858611501, 'blogs'),
#  (0.007028774950267601, 'languagedependence'),
#  (0.006769156290183513, 'boardgamemechanic_cnt'),
#  (0.00617884921762434, 'weblink'),
#  (0.005271617564697072, 'boardgamepublisher_cnt'),
#  (0.004859441053922166, 'numplays_month'),
#  (0.004825124972128436, 'boardgameartist_cnt'),
#  (0.004227837185367492, 'boardgamedesigner_cnt'),
#  (0.0028958683051432347, 'podcast'),
#  (0.0011214320007162416, 'boardgamehonor_cnt'),
#  (0.0010658199432887012, 'minplayers'),
#  (0.0007191324081190794, 'news')]

# %%
plt.pie([a[0] for a in dtr_feature_importance],labels=[a[1] for a in dtr_feature_importance])
plt.show()
