# %%
# Dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# read in csv file
game_info_df=pd.read_csv("../data/boardgames_07022021.csv")
# remove duplicate games
game_info_df.drop_duplicates(subset=['objectid'], inplace=True)
# =========================================================================================================
# choose the features based on correlations
game_info_df=game_info_df[['average', 'numwanting', 'siteviews', 'blogs', 'minage', 'news',
                           'podcast', 'totalvotes', 'numcomments', 'numgeeklists', 'weblink']].copy()
# =========================================================================================================
# remove the rows which have invalid values
game_info_df.drop(game_info_df[game_info_df['average'] ==0].index, inplace = True)
game_info_df.drop(game_info_df[game_info_df['totalvotes'] ==0].index, inplace = True)
# drop the null rows
game_info_df.dropna(inplace=True)
game_info_df.head()
# Out:
#    average  numwanting  siteviews  blogs  minage  news  podcast  totalvotes  \
# 0  8.77503        1374   10583753    690      14     8      147        1171
# 1  8.60721         850    3385064    653      13    10      170         668
# 2  8.66981        1477    1816252    208      14     4       28         521
# 3  8.42870        2085    6059031   1473      12    16      163        1800
# 4  8.68957         979    2267902     99      14     3       53         335
#
#    numcomments  numgeeklists  weblink
# 0         8021          4649       40
# 1         6552          3978       70
# 2         3303          1630       23
# 3        10034          7276       71
# 4         2206          1010       23

# %%
# Get the general idea about the dataset value range
game_info_df.describe().T
# Out:
#                 count          mean            std     min          25%  \
# average       20138.0      6.434485       0.938374     1.0      5.86667
# numwanting    20138.0     43.792879     121.608511     0.0      3.00000
# siteviews     20138.0  92644.494091  261624.524627  1431.0  14757.00000
# blogs         20138.0     12.260701      45.139607     0.0      0.00000
# minage        20138.0      9.598073       3.710556     0.0      8.00000
# news          20138.0      0.580197       1.396812     0.0      0.00000
# podcast       20138.0      2.137899       8.391469     0.0      0.00000
# totalvotes    20138.0     16.454067      66.393870     1.0      2.00000
# numcomments   20138.0    219.157364     676.344229     0.0     23.00000
# numgeeklists  20138.0    259.978101    1183.245497     0.0     24.00000
# weblink       20138.0      6.637352      11.384822     0.0      1.00000
#
#                        50%           75%         max
# average           6.472555      7.058972         9.5
# numwanting        9.000000     30.000000      2085.0
# siteviews     29878.500000  72693.500000  10583753.0
# blogs             2.000000      8.000000      1473.0
# minage           10.000000     12.000000        25.0
# news              0.000000      1.000000        37.0
# podcast           0.000000      1.000000       588.0
# totalvotes        3.000000      9.000000      2108.0
# numcomments      53.000000    146.000000     18840.0
# numgeeklists     63.000000    195.000000    136869.0
# weblink           3.000000      7.000000       207.0

# %% [markdown]
# ## Select features, Scale the data

# %%
# Set features (X) and target (y)
y=game_info_df['average']
X=game_info_df.drop(['average'],axis=1)

# Scale the data
from sklearn.preprocessing import MinMaxScaler
X_scaler = MinMaxScaler().fit(X)
X_scaled = X_scaler.transform(X)

X_scaled.shape, y.shape
# Out:
# ((20138, 10), (20138,))

# %% [markdown]
# ## AdaBoostRegressor

# %%
from sklearn.ensemble import AdaBoostRegressor
 # Create a random forest regressor
abr = AdaBoostRegressor(n_estimators=1000)
abr = abr.fit(X_scaled, y)
print(f"Training Data Score: {abr.score(X_scaled, y):.5f}")
# Out:
# Training Data Score: 0.35736

# %%
# Create the GridSearchCV model
# Create the GridSearch estimator along with a parameter object containing the values to adjust
from sklearn.model_selection import GridSearchCV
param_grid = {'n_estimators': [50,200,500,1000],
              'loss': ['linear', 'square', 'exponential']}
grid = GridSearchCV(abr, param_grid, verbose=3, scoring="neg_mean_squared_error",return_train_score=True)

# Train the model with GridSearch
grid.fit(X_scaled, y)

print(grid.best_params_)
print(grid.best_score_)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV 1/5] END loss=linear, n_estimators=50;, score=(train=-0.617, test=-0.786) total time=   0.4s
# [CV 2/5] END loss=linear, n_estimators=50;, score=(train=-0.596, test=-0.653) total time=   0.4s
# [CV 3/5] END loss=linear, n_estimators=50;, score=(train=-0.535, test=-0.884) total time=   0.5s
# [CV 4/5] END loss=linear, n_estimators=50;, score=(train=-0.597, test=-0.391) total time=   0.3s
# [CV 5/5] END loss=linear, n_estimators=50;, score=(train=-0.368, test=-2.465) total time=   0.7s
# [CV 1/5] END loss=linear, n_estimators=200;, score=(train=-0.610, test=-0.572) total time=   0.3s
# [CV 2/5] END loss=linear, n_estimators=200;, score=(train=-0.582, test=-0.650) total time=   0.4s
# [CV 3/5] END loss=linear, n_estimators=200;, score=(train=-0.523, test=-0.885) total time=   0.2s
# [CV 4/5] END loss=linear, n_estimators=200;, score=(train=-0.626, test=-0.376) total time=   0.3s
# [CV 5/5] END loss=linear, n_estimators=200;, score=(train=-0.360, test=-2.442) total time=   0.6s
# [CV 1/5] END loss=linear, n_estimators=500;, score=(train=-0.621, test=-0.621) total time=   0.3s
# [CV 2/5] END loss=linear, n_estimators=500;, score=(train=-0.565, test=-0.569) total time=   0.2s
# [CV 3/5] END loss=linear, n_estimators=500;, score=(train=-0.518, test=-0.840) total time=   0.4s
# [CV 4/5] END loss=linear, n_estimators=500;, score=(train=-0.647, test=-0.393) total time=   0.6s
# [CV 5/5] END loss=linear, n_estimators=500;, score=(train=-0.351, test=-2.395) total time=   0.4s
# [CV 1/5] END loss=linear, n_estimators=1000;, score=(train=-0.602, test=-0.557) total time=   0.2s
# [CV 2/5] END loss=linear, n_estimators=1000;, score=(train=-0.580, test=-0.625) total time=   0.4s
# [CV 3/5] END loss=linear, n_estimators=1000;, score=(train=-0.551, test=-0.946) total time=   0.6s
# [CV 4/5] END loss=linear, n_estimators=1000;, score=(train=-0.629, test=-0.397) total time=   0.3s
# [CV 5/5] END loss=linear, n_estimators=1000;, score=(train=-0.382, test=-2.521) total time=   0.8s
# [CV 1/5] END loss=square, n_estimators=50;, score=(train=-0.677, test=-1.162) total time=   0.5s
# [CV 2/5] END loss=square, n_estimators=50;, score=(train=-0.631, test=-0.724) total time=   0.5s
# [CV 3/5] END loss=square, n_estimators=50;, score=(train=-0.574, test=-0.923) total time=   0.5s
# [CV 4/5] END loss=square, n_estimators=50;, score=(train=-0.807, test=-0.404) total time=   0.5s
# [CV 5/5] END loss=square, n_estimators=50;, score=(train=-0.466, test=-2.811) total time=   0.5s
# [CV 1/5] END loss=square, n_estimators=200;, score=(train=-0.767, test=-1.290) total time=   1.7s
# [CV 2/5] END loss=square, n_estimators=200;, score=(train=-0.763, test=-1.012) total time=   1.8s
# [CV 3/5] END loss=square, n_estimators=200;, score=(train=-0.634, test=-1.064) total time=   1.7s
# [CV 4/5] END loss=square, n_estimators=200;, score=(train=-0.988, test=-0.443) total time=   1.8s
# [CV 5/5] END loss=square, n_estimators=200;, score=(train=-0.508, test=-2.908) total time=   2.0s
# [CV 1/5] END loss=square, n_estimators=500;, score=(train=-0.841, test=-1.141) total time=   4.4s
# [CV 2/5] END loss=square, n_estimators=500;, score=(train=-0.731, test=-0.988) total time=   4.6s
# [CV 3/5] END loss=square, n_estimators=500;, score=(train=-0.747, test=-1.116) total time=   4.4s
# [CV 4/5] END loss=square, n_estimators=500;, score=(train=-0.998, test=-0.434) total time=   4.5s
# [CV 5/5] END loss=square, n_estimators=500;, score=(train=-0.512, test=-2.959) total time=   5.0s
# [CV 1/5] END loss=square, n_estimators=1000;, score=(train=-0.792, test=-0.944) total time=   8.8s
# [CV 2/5] END loss=square, n_estimators=1000;, score=(train=-0.790, test=-1.065) total time=   8.7s
# [CV 3/5] END loss=square, n_estimators=1000;, score=(train=-0.710, test=-1.123) total time=   8.8s
# [CV 4/5] END loss=square, n_estimators=1000;, score=(train=-1.041, test=-0.455) total time=   8.8s
# [CV 5/5] END loss=square, n_estimators=1000;, score=(train=-0.525, test=-2.972) total time=   9.9s
# [CV 1/5] END loss=exponential, n_estimators=50;, score=(train=-0.651, test=-0.745) total time=   0.5s
# [CV 2/5] END loss=exponential, n_estimators=50;, score=(train=-0.602, test=-0.720) total time=   0.5s
# [CV 3/5] END loss=exponential, n_estimators=50;, score=(train=-0.543, test=-0.911) total time=   0.5s
# [CV 4/5] END loss=exponential, n_estimators=50;, score=(train=-0.654, test=-0.369) total time=   0.6s
# [CV 5/5] END loss=exponential, n_estimators=50;, score=(train=-0.374, test=-2.509) total time=   0.7s
# [CV 1/5] END loss=exponential, n_estimators=200;, score=(train=-0.770, test=-1.064) total time=   1.9s
# [CV 2/5] END loss=exponential, n_estimators=200;, score=(train=-0.871, test=-1.115) total time=   1.9s
# [CV 3/5] END loss=exponential, n_estimators=200;, score=(train=-0.750, test=-1.097) total time=   1.9s
# [CV 4/5] END loss=exponential, n_estimators=200;, score=(train=-1.074, test=-0.402) total time=   1.9s
# [CV 5/5] END loss=exponential, n_estimators=200;, score=(train=-0.483, test=-2.908) total time=   2.3s
# [CV 1/5] END loss=exponential, n_estimators=500;, score=(train=-0.803, test=-1.285) total time=   4.6s
# [CV 2/5] END loss=exponential, n_estimators=500;, score=(train=-0.920, test=-1.135) total time=   4.6s
# [CV 3/5] END loss=exponential, n_estimators=500;, score=(train=-0.878, test=-1.172) total time=   4.5s
# [CV 4/5] END loss=exponential, n_estimators=500;, score=(train=-1.467, test=-0.479) total time=   4.6s
# [CV 5/5] END loss=exponential, n_estimators=500;, score=(train=-0.520, test=-3.003) total time=   5.2s
# [CV 1/5] END loss=exponential, n_estimators=1000;, score=(train=-0.900, test=-1.831) total time=   9.0s
# [CV 2/5] END loss=exponential, n_estimators=1000;, score=(train=-0.992, test=-1.232) total time=   9.2s
# [CV 3/5] END loss=exponential, n_estimators=1000;, score=(train=-0.949, test=-1.245) total time=   8.9s
# [CV 4/5] END loss=exponential, n_estimators=1000;, score=(train=-1.294, test=-0.441) total time=   9.2s
# [CV 5/5] END loss=exponential, n_estimators=1000;, score=(train=-0.543, test=-3.070) total time=  10.3s
# {'loss': 'linear', 'n_estimators': 500}
# -0.9635449488736914

# %%
from sklearn.metrics import explained_variance_score
from sklearn.metrics import r2_score

# get the model predictions
predictions = grid.predict(X_scaled)

print(f"Grid Best Explained Variance Score: {explained_variance_score(y, predictions):.5f}")
print(f"Grid Best R2 Score: {r2_score(y, predictions):.5f}")
# Out:
# Grid Best Explained Variance Score: 0.39258
# Grid Best R2 Score: 0.33835

# %%
# %matplotlib inline

fig = plt.figure()
#add subplots
ax1 = fig.add_subplot(231)
ax2 = fig.add_subplot(233)
# Plot predictions vs actual values
ax1.scatter(predictions, y,alpha=0.2)
ax1.plot([y.min(), y.max()],[y.min(), y.max()],'--r', linewidth=2)
ax1.set_xlim([y.min(), y.max()])
ax1.set_xlabel('Predicted')
ax1.set_ylabel('Actual')
# Plot Residuals
ax2.scatter(predictions, predictions - y,alpha=0.2)
ax2.hlines(y=0, xmin=y.min(), xmax=y.max(),colors="r", linestyles='dashed', )
ax2.set_xlim([y.min(), y.max()])
ax2.set_xlabel('Predicted')
ax2.set_ylabel('Residual')
plt.show()

# %%
fig.savefig("abr.svg", dpi=150)
fig.savefig("abr.png", dpi=150)
